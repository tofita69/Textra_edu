# %%
import pandas as pd

# Load your CSV file
df = pd.read_csv('/home/yassine/Textra-edu/data/summarized_output.csv')

# Display the DataFrame as a table
df
# Out:
#      Chunk Number                                Original Text Chunk  \
# 0               1  UNIVERSITE DR < YAHIA FARES > DE MEDEA Faculté...
# 1               2  Durée : 75 mn Exercice 01 (03 pts : 10 Mn) : R...
# 2               3  est pertinente ? expliquez notamment avec des ...
# 3               4  résultats obtenus par des étudiants de Tronc C...
# 4               5  Techniques ABien Admis décrit par 3 attributs ...
# ..            ...                                                ...
# 143           144                                    1 2 4 0,5 0 0,5
# 144           145                                         10 1 1 2 5
# 145           146                                   0,5 1 1,5 11 1 0
# 146           147  1 6 0,5 0 0,5 Donc, les instances les plus pro...
# 147           148  La distance utilisée est la distante mixte ent...
#
#                                                Summary
# 0    Chunk 1: Researchers at the University of Renn...
# ...
