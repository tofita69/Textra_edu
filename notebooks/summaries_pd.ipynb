# %% [markdown]
# # Cleaning CSVs and merging them

# %%
import os 
import pandas as pd 

def display_csv(input_folder, rows_to_display):

    for filename in os.listdir(input_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(input_folder, filename )
            print(f"\nLoading file: {file_path}")

            try:
                df = pd.read_csv(file_path)

                print(df.head(rows_to_display))

            except Exception as e:
                print(f"Error loading {file_path}: {e}")

# %%
input_folder = "/home/yassine/Textra-edu/csv_outputs"
display_csv(input_folder, rows_to_display=5)
# Out:
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_PIMM_JME_2024_HASCOET.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Open-Loop Control System for ...
# 1             2  Javier Arduengo, Nicolas Hascoet, Francisco Ch...
# 2             3  HAL Id: hal-04675399 https/halsclence/hal-0467...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  Journal ofMachine Engineering, 2024, Vol. 24, ...
#
#                                              Summary
# 0  Chunk 1: This video is part of the HAL Open Sc...
# 1  Chunk 2: Open-Loop Control System for High Pre...
# 2  Chunk 3: The Historical Archive of France (HAL...
# 3  Chunk 4: The aim of this project is to make av...
# 4  Chunk 5: A new method for 3D bioprinting has b...
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_Cours Stochastiques - M. Hadda.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  Polycopié RO pour le GI Modèles stochastiques ...
# 1             2  ENSAM de Meknès Université Moulay Ismail Table...
# 2             3  5 2 Notions générales de probabilités 7 2.1 Es...
# 3             4     7 2.1.1 Espace mesurable 7 2.1.2 Mesurabiité 8
# 4             5  2.1.3 Probabilités conditionnelles : 10 2.1.4 ...
#
#                                              Summary
# 0  Chunk 1: The International Institute for Strat...
# 1  Chunk 2: A chronology of key events in the his...
# 2  Chunk 3: The BBC News website looks at some of...
# 3             Chunk 4: Espace mesurable, mesurabiité
# 4                      Chunk 5: Aléatoires discrtes
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_big-book-of-machine-learning-use-cases-2nd-edition.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1    0 eBook  Big Book of Machine Learning Use Cases
# 1             2  A collection of technical blogs, including cod...
# 2             3  databricks EBOOK: BIG BOOK OF MACHINE LEARNIN ...
# 3             4  Introduction 3 CHAPTER 2: Moneyball 2.0: Impro...
# 4             5  CHAPTER 3: Improving On-Shelf Availability for...
#
#                                              Summary
# 0  Chunk 1: A selection of the best machine learn...
# 1  Chunk 2: BBC News takes a look at some of the ...
# 2   Chunk 3: BBC News NI takes a look at some of the
# 3   Chunk 4: Moneyball 2.0: Improving Pitch-by-Pitch
# 4      Chunk 5: In this session, you'll learn how to
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_PIMM_CRM _ 2019_REILLE.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Incremental dynamic mode deco...
# 1             2  Cueto, Jean Louis Duval, Francisco Chinesta, R...
# 2             3  HAL Id: hal-02561899 https//halscience/la-0256...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  Incremental dynamic mode decomposition: A redu...
#
#                                              Summary
# 0  Chunk 1: Researchers at the Massachusetts Inst...
# 1  Chunk 2: An incremental learner-model operatin...
# 2  Chunk 3: The Historical Archive of London (HAL...
# 3  Chunk 4: The aim of this project is to make av...
# 4  Chunk 5: The following papers have been publis...
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_I2M_AEM_Yadav_2021.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Data Treatment of In Situ Mon...
# 1             2  To cite this version: Pinku Yadav, Olivier Rig...
# 2             3  https/halsclence/hal-0348384V1 Submitted on 16...
# 3             4  entific research documents, whether they are p...
# 4             5  Distributed under a Creative Commons Attributi...
#
#                                              Summary
# 0  Chunk 1: Researchers at the University of Bris...
# 1  Chunk 2: In Situ Monitoring Systems in Selecti...
# 2  Chunk 3: The HAL archive is a multi-disciplina...
# 3  Chunk 4: The National Library of France has a ...
# 4  Chunk 5: The aim of this study is to investiga...
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_applsci-10-05261-v3.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Combining Internal- and Extem...
# 1             2  Montmain, Stéphane Perrey > To cite this versi...
# 2             3  HAL Id: hal-02913576 https//Imt-mines-altes.ha...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  FIFF applied MDPI sciences Article Combining I...
#
#                                              Summary
# 0  Chunk 1: Emmanuel Vallance, Nicolas Sutton-Cha...
# 1  Chunk 2: A new study suggests that a combinati...
# 2  Chunk 3: The archive of the French Academy of ...
# 3  Chunk 4: The aim of this project is to make av...
# 4  Chunk 5: The International Food and Agricultur...
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_gaudez_2023additive-manufacturing.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science A synchrotron transmission X-...
# 1             2  S. Gaudez, M. Ben Haj Slama, E. Heripre, L. Ye...
# 2             3  Additive Manufacturing, 2023, 73, pp.103692. 1...
# 3             4  L'archive ouverte pluridisciplinaire HAL, est ...
# 4             5  abroad, or from public or private research cen...
#
#                                              Summary
# 0  Chunk 1: Researchers at the Massachusetts Inst...
# 1  Chunk 2: A synchrotron transmission X-ray micr...
# 2        Chunk 3: The UK's Department of Defence (Df
# 3  Chunk 4: L'archive ouverte pluriaire HAL, est ...
# 4  Chunk 5: The European Research Council (ERC) i...
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_Thermodynamics-based Artificial Neural Networks for constitutive modeling.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Thermodynamics-based Artifici...
# 1             2  To cite this version: Filippo Masi, Ioannis St...
# 2             3  https//halscience/la-03079127V1 Submitted on 1...
# 3             4  entific research documents, whether they are p...
# 4             5  modeling Filippo Masia,b, Ioannis Stefanou**, ...
#
#                                              Summary
# 0  Chunk 1: Researchers at the Massachusetts Inst...
# 1  Chunk 2: "Themmodynamic-based Neural Networks"...
# 2  Chunk 3: The HAL archive is a multi-disciplina...
# 3  Chunk 4: The aim of this project is to bring t...
# 4  Chunk 5: In: Proceedings of the 6th Internatio...
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_output_15.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  UNIVERSITE DR < YAHIA FARES > DE MEDEA Faculté...
# 1             2  Durée : 75 mn Exercice 01 (03 pts : 10 Mn) : R...
# 2             3  est pertinente ? expliquez notamment avec des ...
# 3             4  résultats obtenus par des étudiants de Tronc C...
# 4             5  Techniques ABien Admis décrit par 3 attributs ...
#
#                                              Summary
# 0  Chunk 1: Researchers at the University of Renn...
# 1  Chunk 2: Durée : 75 Exercice 01 (03 pts : 10 M...
# 2  Chunk 3: Le tableau suivant contient des dons ...
# 3                     Chunk 4: Chaque étudiant s'est
# 4              Chunk 5: Une Technique ABien Admis s'
#
# Loading file: /home/yassine/Textra-edu/csv_outputs/summarized_122-SOUDOPLATOF_2018-02-16_web-1.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  Février 2018 LINTELLIGENCE ARIIFICIELLE: EXPER...
# 1             2  FONDATION POUI R LINNOVATION POLITIQUE fondapo...
# 2             3  FONDATION POUR L'INNOVATION POLITIQUE fondapol...
# 3             4  INTELLIGENCE ARTIFICIELLE: LEXPERTISE PARTOUT ...
# 4             5  L'INNOVATION POLITIQUE fondapol.org Lal Fondat...
#
#                                              Summary
# 0  Chunk 1: A selection of photos from around the...
# 1       Chunk 2: All photographs  Serge SOUDOPLATOFF
# 2  Chunk 3: All photographs courtesy of AFP, EPA,...
# 3   Chunk 4: All photographs  AFP, EPA, Getty Images
# 4  Chunk 5: Lal Fondation pour l'innovation polit...

# %%
def clean_summary_column(input_folder, output_folder):
    """
    Removes the 'Chunk X: ' prefix from the 'Summary' column in all CSV files in a folder.

    Parameters:
    - input_folder: Path to the folder containing input CSV files.
    - output_folder: Path to save the cleaned CSV files.
    """
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all CSV files in the folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.csv'):
            input_csv_path = os.path.join(input_folder, filename)
            output_csv_path = os.path.join(output_folder, filename)

            print(f"Processing file: {input_csv_path}")

            # Load the CSV file
            df = pd.read_csv(input_csv_path)

            # Clean the 'Summary' column by removing the 'Chunk X: ' prefix
            if "Summary" in df.columns:
                df["Summary"] = df["Summary"].str.replace(r'^Chunk \d+: ', '', regex=True)

            # Save the cleaned DataFrame to a new CSV file
            df.to_csv(output_csv_path, index=False, encoding='utf-8')
            print(f"Cleaned file saved to: {output_csv_path}")
            print(df.head())

# %%
output_folder = "/home/yassine/Textra-edu/csv_outputs_cleaned"
clean_summary_column(input_folder, output_folder)
# Out:
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_PIMM_JME_2024_HASCOET.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_PIMM_JME_2024_HASCOET.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Open-Loop Control System for ...
# 1             2  Javier Arduengo, Nicolas Hascoet, Francisco Ch...
# 2             3  HAL Id: hal-04675399 https/halsclence/hal-0467...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  Journal ofMachine Engineering, 2024, Vol. 24, ...
#
#                                              Summary
# 0  This video is part of the HAL Open Science pro...
# 1  Open-Loop Control System for High Precision Ex...
# 2        The Historical Archive of France (HAL) is a
# 3  The aim of this project is to make available t...
# 4  A new method for 3D bioprinting has been devel...
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_Cours Stochastiques - M. Hadda.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_Cours Stochastiques - M. Hadda.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  Polycopié RO pour le GI Modèles stochastiques ...
# 1             2  ENSAM de Meknès Université Moulay Ismail Table...
# 2             3  5 2 Notions générales de probabilités 7 2.1 Es...
# 3             4     7 2.1.1 Espace mesurable 7 2.1.2 Mesurabiité 8
# 4             5  2.1.3 Probabilités conditionnelles : 10 2.1.4 ...
#
#                                              Summary
# 0  The International Institute for Strategic Stud...
# 1   A chronology of key events in the history of the
# 2      The BBC News website looks at some of the key
# 3                      Espace mesurable, mesurabiité
# 4                               Aléatoires discrtes
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_big-book-of-machine-learning-use-cases-2nd-edition.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_big-book-of-machine-learning-use-cases-2nd-edition.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1    0 eBook  Big Book of Machine Learning Use Cases
# 1             2  A collection of technical blogs, including cod...
# 2             3  databricks EBOOK: BIG BOOK OF MACHINE LEARNIN ...
# 3             4  Introduction 3 CHAPTER 2: Moneyball 2.0: Impro...
# 4             5  CHAPTER 3: Improving On-Shelf Availability for...
#
#                                              Summary
# 0  A selection of the best machine learning and a...
# 1          BBC News takes a look at some of the best
# 2            BBC News NI takes a look at some of the
# 3            Moneyball 2.0: Improving Pitch-by-Pitch
# 4               In this session, you'll learn how to
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_PIMM_CRM _ 2019_REILLE.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_PIMM_CRM _ 2019_REILLE.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Incremental dynamic mode deco...
# 1             2  Cueto, Jean Louis Duval, Francisco Chinesta, R...
# 2             3  HAL Id: hal-02561899 https//halscience/la-0256...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  Incremental dynamic mode decomposition: A redu...
#
#                                              Summary
# 0  Researchers at the Massachusetts Institute of ...
# 1  An incremental learner-model operating at the ...
# 2      The Historical Archive of London (HAL) is the
# 3  The aim of this project is to make available t...
# 4  The following papers have been published in th...
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_I2M_AEM_Yadav_2021.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_I2M_AEM_Yadav_2021.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Data Treatment of In Situ Mon...
# 1             2  To cite this version: Pinku Yadav, Olivier Rig...
# 2             3  https/halsclence/hal-0348384V1 Submitted on 16...
# 3             4  entific research documents, whether they are p...
# 4             5  Distributed under a Creative Commons Attributi...
#
#                                              Summary
# 0  Researchers at the University of Bristol have ...
# 1  In Situ Monitoring Systems in Selective Laser ...
# 2  The HAL archive is a multi-disciplinary open a...
# 3  The National Library of France has a collectio...
# 4  The aim of this study is to investigate the ef...
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_applsci-10-05261-v3.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_applsci-10-05261-v3.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Combining Internal- and Extem...
# 1             2  Montmain, Stéphane Perrey > To cite this versi...
# 2             3  HAL Id: hal-02913576 https//Imt-mines-altes.ha...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  FIFF applied MDPI sciences Article Combining I...
#
#                                              Summary
# 0         Emmanuel Vallance, Nicolas Sutton-Charani,
# 1  A new study suggests that a combination of int...
# 2  The archive of the French Academy of Sciences ...
# 3  The aim of this project is to make available t...
# 4  The International Food and Agriculture Organiz...
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_gaudez_2023additive-manufacturing.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_gaudez_2023additive-manufacturing.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science A synchrotron transmission X-...
# 1             2  S. Gaudez, M. Ben Haj Slama, E. Heripre, L. Ye...
# 2             3  Additive Manufacturing, 2023, 73, pp.103692. 1...
# 3             4  L'archive ouverte pluridisciplinaire HAL, est ...
# 4             5  abroad, or from public or private research cen...
#
#                                              Summary
# 0  Researchers at the Massachusetts Institute of ...
# 1  A synchrotron transmission X-ray microscopy st...
# 2                 The UK's Department of Defence (Df
# 3  L'archive ouverte pluriaire HAL, est archive f...
# 4  The European Research Council (ERC) is a membe...
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_Thermodynamics-based Artificial Neural Networks for constitutive modeling.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_Thermodynamics-based Artificial Neural Networks for constitutive modeling.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Thermodynamics-based Artifici...
# 1             2  To cite this version: Filippo Masi, Ioannis St...
# 2             3  https//halscience/la-03079127V1 Submitted on 1...
# 3             4  entific research documents, whether they are p...
# 4             5  modeling Filippo Masia,b, Ioannis Stefanou**, ...
#
#                                              Summary
# 0  Researchers at the Massachusetts Institute of ...
# 1  "Themmodynamic-based Neural Networks" by Filip...
# 2  The HAL archive is a multi-disciplinary open a...
# 3  The aim of this project is to bring together a...
# 4  In: Proceedings of the 6th International Confe...
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_output_15.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_output_15.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  UNIVERSITE DR < YAHIA FARES > DE MEDEA Faculté...
# 1             2  Durée : 75 mn Exercice 01 (03 pts : 10 Mn) : R...
# 2             3  est pertinente ? expliquez notamment avec des ...
# 3             4  résultats obtenus par des étudiants de Tronc C...
# 4             5  Techniques ABien Admis décrit par 3 attributs ...
#
#                                              Summary
# 0  Researchers at the University of Rennes in Fra...
# 1  Durée : 75 Exercice 01 (03 pts : 10 Mn) : Répo...
# 2    Le tableau suivant contient des dons sur les No
# 3                              Chaque étudiant s'est
# 4                       Une Technique ABien Admis s'
# Processing file: /home/yassine/Textra-edu/csv_outputs/summarized_122-SOUDOPLATOF_2018-02-16_web-1.csv
# Cleaned file saved to: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_122-SOUDOPLATOF_2018-02-16_web-1.csv
#    Chunk Number                                Original Text Chunk  \
# 0             1  Février 2018 LINTELLIGENCE ARIIFICIELLE: EXPER...
# 1             2  FONDATION POUI R LINNOVATION POLITIQUE fondapo...
# 2             3  FONDATION POUR L'INNOVATION POLITIQUE fondapol...
# 3             4  INTELLIGENCE ARTIFICIELLE: LEXPERTISE PARTOUT ...
# 4             5  L'INNOVATION POLITIQUE fondapol.org Lal Fondat...
#
#                                              Summary
# 0  A selection of photos from around the world th...
# 1                All photographs  Serge SOUDOPLATOFF
# 2  All photographs courtesy of AFP, EPA, Getty Im...
# 3            All photographs  AFP, EPA, Getty Images
# 4      Lal Fondation pour l'innovation politique est

# %%
import os
import pandas as pd

def merge_csv_files(input_folder, output_file):
    """
    Merges all CSV files in a specified folder into a single CSV file.

    Parameters:
    - input_folder: Path to the folder containing the CSV files to merge.
    - output_file: Path to save the consolidated CSV file.
    """
    # List to hold DataFrames
    data_frames = []

    # Iterate through all CSV files in the folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.csv'):
            file_path = os.path.join(input_folder, filename)
            print(f"Processing file: {file_path}")

            # Load the CSV file into a DataFrame
            df = pd.read_csv(file_path)

            # Add a column for the source file name
            df["Source File"] = filename

            # Append the DataFrame to the list
            data_frames.append(df)

    # Concatenate all DataFrames
    if data_frames:
        merged_df = pd.concat(data_frames, ignore_index=True)

        # Save the merged DataFrame to a CSV file
        merged_df.to_csv(output_file, index=False, encoding='utf-8')
        print(f"All files merged and saved to: {output_file}")
    else:
        print("No CSV files found in the input folder.")

# %%
merge_csv_files(output_folder,"/home/yassine/Textra-edu/merged.csv" )
# Out:
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_PIMM_JME_2024_HASCOET.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_Cours Stochastiques - M. Hadda.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_big-book-of-machine-learning-use-cases-2nd-edition.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_PIMM_CRM _ 2019_REILLE.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_I2M_AEM_Yadav_2021.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_applsci-10-05261-v3.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_gaudez_2023additive-manufacturing.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_Thermodynamics-based Artificial Neural Networks for constitutive modeling.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_output_15.csv
# Processing file: /home/yassine/Textra-edu/csv_outputs_cleaned/summarized_122-SOUDOPLATOF_2018-02-16_web-1.csv
# All files merged and saved to: /home/yassine/Textra-edu/merged.csv

# %%
data_merged = pd.read_csv("/home/yassine/Textra-edu/merged.csv")

# %%
data_merged.head()
# Out:
#    Chunk Number                                Original Text Chunk  \
# 0             1  HAL open science Open-Loop Control System for ...
# 1             2  Javier Arduengo, Nicolas Hascoet, Francisco Ch...
# 2             3  HAL Id: hal-04675399 https/halsclence/hal-0467...
# 3             4  archive for the deposit and dissemination of s...
# 4             5  Journal ofMachine Engineering, 2024, Vol. 24, ...
#
#                                              Summary  \
# 0  This video is part of the HAL Open Science pro...
# 1  Open-Loop Control System for High Precision Ex...
# 2        The Historical Archive of France (HAL) is a
# 3  The aim of this project is to make available t...
# 4  A new method for 3D bioprinting has been devel...
#
#                             Source File
# 0  summarized_PIMM_JME_2024_HASCOET.csv
# 1  summarized_PIMM_JME_2024_HASCOET.csv
# 2  summarized_PIMM_JME_2024_HASCOET.csv
# 3  summarized_PIMM_JME_2024_HASCOET.csv
# 4  summarized_PIMM_JME_2024_HASCOET.csv
